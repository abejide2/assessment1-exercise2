# %% [markdown]
# <a href="https://colab.research.google.com/github/abejide2/assessment1-exercise2/blob/main/Assignment_on_Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment on Tuple**

# %% [markdown]
# Consider the following tuple:

# %%
# sample tuple

genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco")

# %% [markdown]
# Find the length of the tuple, <code>genres_tuple</code>:

# %%
# Write your code below and press Shift+Enter to execute

# %%
print(len(genres_tuple))
# Out:
# 8

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%202/images/TuplesQuiz.png" width="1100" align="center">

# %% [markdown]
# Access the element, with respect to index 3:

# %%
# Write your code below and press Shift+Enter to execute

# %%
print(genres_tuple[2])
# Out:
# soul

# %% [markdown]
# Use slicing to obtain indexes 3, 4 and 5:

# %%
# Write your code below and press Shift+Enter to execute

# %%
print(genres_tuple[2],genres_tuple[3],genres_tuple[4])
# Out:
# soul hard rock soft rock

# %% [markdown]
# Find the first two elements of the tuple <code>genres_tuple</code>:

# %%
# Write your code below and press Shift+Enter to execute

# %%
print(genres_tuple[:2])
# Out:
# ('pop', 'rock')

# %% [markdown]
# Find the first index of <code>"disco"</code>:

# %%
# Write your code below and press Shift+Enter to execute

# %%
import re
print(genres_tuple[0])
# Out:
# pop

# %% [markdown]
# Generate a sorted List from the Tuple <code>C_tuple=(-5, 1, -3)</code>:

# %%
# Write your code below and press Shift+Enter to execute

# %%
print(genres_tuple[-5],genres_tuple[1],genres_tuple[-3])
# Out:
# hard rock rock R&B
